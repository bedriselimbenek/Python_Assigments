# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # task1

# %%
user = float(input("Please enter Celsius temperature: "))
convert_temp = user * 1.8 + 32

print(f"{user} degree Celsius is", convert_temp, "degrees Fahrenheit.")
# Out:
# Please enter Celsius temperature: 15
# 15.0 degree Celsius is 59.0 degrees Fahrenheit.

# %% [markdown]
# # task2

# %%
user = float(input("Please enter a distance in kilometers: "))

mile_convert = user * 0.621371 

print(f"{user} kilometers is", mile_convert, "miles")
# Out:
# Please enter a distance in kilometers: 25
# 25.0 kilometers is 15.534275000000001 miles
