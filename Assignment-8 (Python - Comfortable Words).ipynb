# %% [markdown]
# # Assignment-8 (Python - Comfortable Words)
# ![image.png](attachment:image.png)

# %%
left_hand = ("q", "w", "e", "r", "t", "a", "s", "d", "f", "g", "z", "x", "c", "v", "b")
right_hand = ("y", "u", "i", "o", "p", "h", "j", "k", "l", "n", "m")
word = set(input("Bir kelime giriniz: "))

comfort_word = bool((word.intersection(left_hand) and word.intersection(right_hand))

if comfort_word:
    print(True)
else:
    print(False)
# Out:
# Bir kelime giriniz: clarusway
# True

# %%
word.intersection(right_hand)
# Out:
# set()

# %%
word.intersection(left_hand)
# Out:
# {'a'}

# %%
kelime=set(input( ))
left_hand = ("q", "w", "e", "r", "t", "a", "s", "d", "f", "g", "z", "x", "c", "v", "b")
right_hand = ("y", "u", "i", "o", "p", "h", "j", "k", "l", "n", "m")
sol=bool(kelime.difference(left_hand))
sag=bool(kelime.difference (right_hand))
print(sol and sag)
# Out:
# tester
# False

# %%
bool(word.intersection(left_hand))
# Out:
# True

# %% [markdown]
# # Edwin hoca lab çözümü
